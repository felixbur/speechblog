# %% [markdown]
# Predict emotions from emodb with a multi layer perceptron

# %%
import audformat
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import os
import opensmile
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import recall_score
# Out:
# /home/felix/data/envs/researchEnv/lib/python3.8/site-packages/opensmile/core/single.py:74: UserWarning: 'ignore_vars' argument is deprecated and will be removed with version 0.5.0. Use 'hide' instead.
#   @audobject.init_decorator(
# /home/felix/data/envs/researchEnv/lib/python3.8/site-packages/opensmile/core/multi.py:45: UserWarning: 'ignore_vars' argument is deprecated and will be removed with version 0.5.0. Use 'hide' instead.
#   @audobject.init_decorator(

# %%
# get and unpack the Berlin Emodb emotional database if not already there
if not os.path.isdir('./emodb/'):
    # !wget -c https://tubcloud.tu-berlin.de/s/LzPWz83Fjneb6SP/download
    # !mv download emodb_audformat.zip
    # !unzip emodb_audformat.zip
    # !rm emodb_audformat.zip
# prepare the dataframe
db = audformat.Database.load('./emodb')
root = './emodb/'
db.map_files(lambda x: os.path.join(root, x))    
df_emotion = db.tables['emotion'].df
df = db.tables['files'].df
# copy the emotion label from the the emotion dataframe to the files dataframe
df['emotion'] = df_emotion['emotion']

# %%
# Encode the emotion words as numbers and use this as target 
target = 'enc_emo'
encoder = LabelEncoder()
encoder.fit(df['emotion'])
df[target] = encoder.transform(df['emotion'])

# %%
df.head()
# Out:
#                                          duration speaker transcription  \
# file
# ./emodb/wav/03a01Fa.wav    0 days 00:00:01.898250       3           a01
# ./emodb/wav/03a01Nc.wav    0 days 00:00:01.611250       3           a01
# ./emodb/wav/03a01Wa.wav 0 days 00:00:01.877812500       3           a01
# ./emodb/wav/03a02Fc.wav    0 days 00:00:02.006250       3           a02
# ./emodb/wav/03a02Nc.wav 0 days 00:00:01.439812500       3           a02
#
#                            emotion  enc_emo
# file
# ./emodb/wav/03a01Fa.wav  happiness        4
# ./emodb/wav/03a01Nc.wav    neutral        5
# ./emodb/wav/03a01Wa.wav      anger        0
# ./emodb/wav/03a02Fc.wav  happiness        4
# ./emodb/wav/03a02Nc.wav    neutral        5

# %%
df.speaker.unique()
# Out:
# [3, 8, 9, 10, 11, 12, 13, 14, 15, 16]
# Categories (10, object): [3, 8, 9, 10, ..., 13, 14, 15, 16]

# %%
train_spkrs
# Out:
# [12, 13, 14, 15, 16]
# Categories (10, object): [3, 8, 9, 10, ..., 13, 14, 15, 16]

# %%
# define fixed speaker disjunct train and test sets
train_spkrs = df.speaker.unique()[5:]
test_spkrs = df.speaker.unique()[:5]
df_train = df[df.speaker.isin(train_spkrs)]
df_test = df[df.speaker.isin(test_spkrs)]

print(f'#train samples: {df_train.shape[0]}, #test samples: {df_test.shape[0]}')
# Out:
# #train samples: 292, #test samples: 243

# %%
# extract (or get) GeMAPS features
if os.path.isfile('feats_train.pkl'):
    feats_train = pd.read_pickle('feats_train.pkl')
    feats_test = pd.read_pickle('feats_test.pkl')
else:
    smile = opensmile.Smile(
        feature_set=opensmile.FeatureSet.GeMAPSv01b,
        feature_level=opensmile.FeatureLevel.Functionals,
    )
    feats_train = smile.process_files(df_train.index)
    feats_test = smile.process_files(df_test.index)
    feats_train.to_pickle('feats_train.pkl')
    feats_test.to_pickle('feats_test.pkl')

#
#                                                           StddevVoicedSegmentLengthSec  \
# file                    start  end
# ./emodb/wav/12a01Fb.wav 0 days 0 days 00:00:01.863625                         0.081316
# ./emodb/wav/12a01Lb.wav 0 days 0 days 00:00:01.886562500                      0.058856
# ./emodb/wav/12a01Nb.wav 0 days 0 days 00:00:01.721937500                      0.101193
# ./emodb/wav/12a01Wc.wav 0 days 0 days 00:00:02.358812500                      0.091043
# ./emodb/wav/12a02Ac.wav 0 days 0 days 00:00:01.225500                         0.048990
#
#                                                           MeanUnvoicedSegmentLength  \
# file                    start  end
# ./emodb/wav/12a01Fb.wav 0 days 0 days 00:00:01.863625                      0.105714
# ./emodb/wav/12a01Lb.wav 0 days 0 days 00:00:01.886562500                   0.181667
# ./emodb/wav/12a01Nb.wav 0 days 0 days 00:00:01.721937500                   0.125000
# ./emodb/wav/12a01Wc.wav 0 days 0 days 00:00:02.358812500                   0.125714
# ./emodb/wav/12a02Ac.wav 0 days 0 days 00:00:01.225500                      0.078571
#
#                                                           StddevUnvoicedSegmentLength
# file                    start  end
# ./emodb/wav/12a01Fb.wav 0 days 0 days 00:00:01.863625                        0.059966
# ./emodb/wav/12a01Lb.wav 0 days 0 days 00:00:01.886562500                     0.210033
# ./emodb/wav/12a01Nb.wav 0 days 0 days 00:00:01.721937500                     0.079739
# ./emodb/wav/12a01Wc.wav 0 days 0 days 00:00:02.358812500                     0.061146
# ./emodb/wav/12a02Ac.wav 0 days 0 days 00:00:01.225500                        0.029966
#
# [5 rows x 62 columns]

# %%
# Perform a standard scaling / z-transformation on the features (mean=0, std=1)
scaler = StandardScaler()
scaler.fit(feats_train)
feats_train_norm = pd.DataFrame(scaler.transform(feats_train))
feats_test_norm = pd.DataFrame(scaler.transform(feats_test))

# %%
feats_test.head(10)
# Out:
#                                                           F0semitoneFrom27.5Hz_sma3nz_amean  \
# file                    start  end
# ./emodb/wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                             31.188164
# ./emodb/wav/03a01Nc.wav 0 days 0 days 00:00:01.611250                             25.022936
# ./emodb/wav/03a01Wa.wav 0 days 0 days 00:00:01.877812500                          34.292316
# ./emodb/wav/03a02Fc.wav 0 days 0 days 00:00:02.006250                             37.576569
# ./emodb/wav/03a02Nc.wav 0 days 0 days 00:00:01.439812500                          25.040188
# ./emodb/wav/03a02Ta.wav 0 days 0 days 00:00:01.735687500                          23.199287
# ./emodb/wav/03a02Wb.wav 0 days 0 days 00:00:02.123625                             34.944218
# ./emodb/wav/03a02Wc.wav 0 days 0 days 00:00:01.498062500                          38.265858
# ./emodb/wav/03a04Ad.wav 0 days 0 days 00:00:01.504874999                          37.341007
# ./emodb/wav/03a04Fd.wav 0 days 0 days 00:00:01.696812500                          33.902008
#
#                                                           F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# file                    start  end
# ./emodb/wav/03a01Fa.wav 0 days 0 days 00:00:01.898250                                   0.152560
# ./emodb/wav/03a01Nc.wav 0 days 0 days 00:00:01.611250                                   0.148540
# ./emodb/wav/03a01Wa.wav 0 days 0 days 00:00:01.877812500                                0.102067
# ./emodb/wav/03a02Fc.wav 0 days 0 days 00:00:02.006250                                   0.108607
# ./emodb/wav/03a02Nc.wav 0 days 0 days 00:00:01.439812
# 3 -0.392215 -0.814042  0.760624  0.921590 -0.171400 -0.504452
# 4  1.619780  0.504738 -0.585935 -0.157731 -0.425440 -0.731378
# 5  1.683307 -0.301575 -1.053108 -1.035977  1.067047  0.711159
# 6  0.898481  1.389360 -1.092803 -1.083471  0.209661 -0.724486
# 7  0.586169  1.176440 -0.764560 -0.711821 -0.742990 -0.654091
# 8 -0.941666  2.848720 -1.297000 -1.224809 -1.018201 -0.724675
# 9 -1.446397  2.052299 -1.211123 -0.971034 -0.721820 -0.710968
#
# [10 rows x 62 columns]

# %%
def get_loader(df_x, df_y):
    data=[]
    for i in range(len(df_x)):
       data.append([df_x.values[i], df_y[target][i]])
    return torch.utils.data.DataLoader(data, shuffle=True, batch_size=8)
trainloader = get_loader(feats_train_norm, df_train)
testloader = get_loader(feats_test_norm, df_test)

# %%
feats_train_norm.shape[1]
# Out:
# 62

# %%
encoder.classes_
# Out:
# array(['anger', 'boredom', 'disgust', 'fear', 'happiness', 'neutral',
#        'sadness'], dtype=object)

# %%
class MLP(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = torch.nn.Sequential(
            torch.nn.Linear(feats_train_norm.shape[1], 16),
            torch.nn.ReLU(),
            torch.nn.Linear(16, len(encoder.classes_))
        )
    def forward(self, x):
        # x: (batch_size, channels, samples)
        x = x.squeeze(dim=1)
        return self.linear(x)

# %%
def train_epoch(model, loader, device, optimizer, criterion):
    model.train()
    losses = []
    for features, labels in loader:
        logits = model(features.to(device))
        loss = criterion(logits, labels.to(device))
        losses.append(loss.item())
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    return (np.asarray(losses)).mean()

def evaluate_model(model, loader, device, encoder):
    logits = torch.zeros(len(loader.dataset), len(encoder.classes_))
    targets = torch.zeros(len(loader.dataset))
    model.eval()
    with torch.no_grad():
        for index, (features, labels) in enumerate(loader):
            start_index = index * loader.batch_size
            end_index = (index + 1) * loader.batch_size
            if end_index > len(loader.dataset):
                end_index = len(loader.dataset)
            logits[start_index:end_index, :] = model(features.to(device))
            targets[start_index:end_index] = labels

    predictions = logits.argmax(dim=1)
    uar = recall_score(targets.numpy(), predictions.numpy(), average='macro')
    return uar, predictions, targets

# %%
device = 'cpu'
model = MLP().to(device)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
epoch_num = 250
uars_train = []
uars_dev = []
losses = []

# %%
for epoch in range(0, epoch_num):
    loss = train_epoch(model, trainloader, device, optimizer, criterion)
    losses.append(loss)
    acc_train = evaluate_model(model, trainloader, device, encoder)[0]
    uars_train.append(acc_train)
    acc_dev, preds, truths = evaluate_model(model, testloader, device, encoder)
    uars_dev.append(acc_dev)
# scale the losses so they fit on the picture
losses = np.asarray(losses)/2

# %%
plt.figure(dpi=100)
plt.plot(uars_train, 'green', label='train set') 
plt.plot(uars_dev, 'red', label='dev set')
plt.plot(losses, 'grey', label='losses/2')
plt.xlabel('eopchs')
plt.ylabel('UAR')
plt.legend()
plt.show()

# %%
encoder.
# Out:
# array(['anger', 'boredom', 'disgust', 'fear', 'happiness', 'neutral',
#        'sadness'], dtype=object)

# %%
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(truths, preds,  normalize = 'true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=encoder.classes_).plot(cmap='gray')
